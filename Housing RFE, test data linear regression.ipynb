# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df=pd.read_csv("Housing (1).csv")
df
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000   7420         4          2        3      yes        no
# 1    12250000   8960         4          4        4      yes        no
# 2    12250000   9960         3          2        2      yes        no
# 3    12215000   7500         4          2        2      yes        no
# 4    11410000   7420         4          1        2      yes       yes
# 5    10850000   7500         3          3        1      yes        no
# 6    10150000   8580         4          3        4      yes        no
# 7    10150000  16200         5          3        2      yes        no
# 8     9870000   8100         4          1        2      yes       yes
# 9     9800000   5750         3          2        4      yes       yes
# 10    9800000  13200         3          1        2      yes        no
# 11    9681000   6000         4          3        2      yes       yes
# 12    9310000   6550         4          2        2      yes        no
# 13    9240000   3500         4          2        2      yes        no
# 14    9240000   7800         3          2        2      yes        no
# 15    9100000   6000         4          1        2      yes        no
# 16    9100000   6600         4          2        2      yes       yes
# 17    8960000   8500         3          2        4      yes        no
# 18    8890000   4600         3          2        2      yes       yes
# 19    8855000   6420         3          2        2      yes        no
# 20    8750000   4320         3          1        2      yes        no
# 21    8680000   7155         3          2        1      yes       yes
# 22    8645000   8050         3          1        1      yes       yes
# 23    8645000   4560         3          2        2      yes       yes
# 24    8575000   8800         3          2        2      yes        no
# 25    8540000   6540         4          2        2      yes       yes
# 26    8463000   6000         3          2        4      yes       yes
# 27    8400000   8875         3          1        1      yes        no
# 28    8400000   7950         5          2        2      yes        no
# 29    8400000   5500         4          2        2      yes        no
# ..        ...    ...       ...        ...      ...      ...       ...
# 515   2450000   3210         3          1        2      yes        no
# 516   2450000   3240         2          1        1       no       yes
# 517   2450000   3000         2          1        1      yes        no
# 518   2450000   3500         2          1        1      yes       yes
# 519   2450000   4840         2          1        2      yes        no
# 520   2450000   7700         2          1        1      yes        no
# 521   2408000   3635         2          1        1       no        no
# 522   2380000   2475         3          1        2      yes        no
# 523   2380000   2787         4          2        2      yes        no
# 524   2380000   3264         2          1        1      yes        no
# 525   2345000   3640         2          1        1      yes        no
# 526   2310000   3180         2          1        1      yes        no
# 527   2275000   1836         2          1        1       no        no
# 528   2275000   3970         1          1        1       no        no
# 529   2275000   3970         3          1        2      yes        no
# 530   2240000   1950         3          1        1       no        no
# 531   2233000   5300         3          1        1       no        no
# 532   2135000   3000         2          1        1       no        no
# 533   2100000   2400         3          1        2      yes        no
# 534   2100000   3000         4          1        2      yes        no
# 535   2100000   3360         2          1        1      yes        no
# 536   1960000   3420         5          1        2       no        no
# 537   1890000   1700         3          1        2      yes        no
# 538   1890000   3649         2          1        1      yes        no
# 539   1855000   2990         2          1        1       no        no
# 540   1820000   3000         2          1        1      yes        no
# 541   1767150   2400         3          1        1       no        no
# 542   1750000   3620         2          1        1      yes        no
# 543   1750000   2910         3          1        1       no        no
# 544   1750000   3850         3          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 0         no              no             yes        2      yes
# 1         no              no             yes        3       no
# 2        yes              no              no        2      yes
# 3        yes              no             yes        3      yes
# 4        yes              no             yes        2       no
# 5        yes              no             yes        2      yes
# 6         no              no             yes        2      yes
# 7         no              no              no        0       no
# 8        yes              no             yes        2      yes
# 9         no              no             yes        1      yes
# 10       yes              no             yes        2      yes
# 11       yes             yes              no        2       no
# 12        no              no             yes        1      yes
# 13        no             yes              no        2       no
# 14        no              no              no        0      yes
# 15       yes              no              no        2       no
# 16       yes              no             yes        1      yes
# 17        no              no             yes        2       no
# 18        no              no             yes        2       no
# 19        no              no             yes        1      yes
# 20       yes             yes              no        2       no
# 21       yes              no             yes        2       no
# 22       yes              no             yes        1       no
# 23       yes              no             yes        1       no
# 24        no              no             yes        2       no
# 25       yes              no             yes        2      yes
# 26       yes              no             yes        0      yes
# 27        no              no              no        1       no
# 28       yes             yes              no        2       no
# 29       yes              no             yes        1      yes
# ..       ...             ...             ...      ...      ...
# 515      yes              no              no        0       no
# 516       no              no              no        1       no
# 517       no              no              no        1       no
# 518       no              no              no        0       no
# 519       no              no              no        0       no
# 520       no              no              no        0       no
# 521       no              no              no        0       no
# 522       no              no              no        0       no
# 523       no              no              no        0       no
# 524       no              no              no        0       no
# 525       no              no              no        0       no
# 526       no              no              no        0       no
# 527      yes              no              no        0       no
# 528       no              no              no        0       no
# 529      yes              no              no        0       no
# 530       no             yes              no        0       no
# 531       no              no             yes        0      yes
# 532       no              no              no        0       no
# 533       no              no              no        0       no
# 534       no              no              no        0       no
# 535       no              no              no        1       no
# 536       no              no              no        0       no
# 537       no              no              no        0       no
# 538       no              no              no        0       no
# 539       no              no              no        1       no
# 540      yes              no              no        2       no
# 541       no              no              no        0       no
# 542       no              no              no        0       no
# 543       no              no              no        0       no
# 544       no              no              no        0       no
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# 3          furnished
# 4          furnished
# 5     semi-furnished
# 6     semi-furnished
# 7        unfurnished
# 8          furnished
# 9        unfurnished
# 10         furnished
# 11    semi-furnished
# 12    semi-furnished
# 13         furnished
# 14    semi-furnished
# 15    semi-furnished
# 16       unfurnished
# 17         furnished
# 18         furnished
# 19    semi-furnished
# 20    semi-furnished
# 21       unfurnished
# 22         furnished
# 23         furnished
# 24         furnished
# 25         furnished
# 26    semi-furnished
# 27    semi-furnished
# 28       unfurnished
# 29    semi-furnished
# ..               ...
# 515      unfurnished
# 516      unfurnished
# 517      unfurnished
# 518      unfurnished
# 519      unfurnished
# 520      unfurnished
# 521      unfurnished
# 522        furnished
# 523        furnished
# 524      unfurnished
# 525      unfurnished
# 526      unfurnished
# 527   semi-furnished
# 528      unfurnished
# 529      unfurnished
# 530      unfurnished
# 531      unfurnished
# 532      unfurnished
# 533      unfurnished
# 534      unfurnished
# 535      unfurnished
# 536      unfurnished
# 537      unfurnished
# 538      unfurnished
# 539      unfurnished
# 540      unfurnished
# 541   semi-furnished
# 542      unfurnished
# 543        furnished
# 544      unfurnished
#
# [545 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
# price               545 non-null int64
# area                545 non-null int64
# bedrooms            545 non-null int64
# bathrooms           545 non-null int64
# stories             545 non-null int64
# mainroad            545 non-null object
# guestroom           545 non-null object
# basement            545 non-null object
# hotwaterheating     545 non-null object
# airconditioning     545 non-null object
# parking             545 non-null int64
# prefarea            545 non-null object
# furnishingstatus    545 non-null object
# dtypes: int64(6), object(7)
# memory usage: 55.4+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
sns.pairplot(df)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.mainroad=le.fit_transform(df["mainroad"])
df.guestroom=le.fit_transform(df["guestroom"])
df.basement=le.fit_transform(df["basement"])
df.airconditioning=le.fit_transform(df["airconditioning"])
df.hotwaterheating=le.fit_transform(df["hotwaterheating"])
df.prefarea=le.fit_transform(df["prefarea"])
df.head(4)
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished

# %%
status=pd.get_dummies(df['furnishingstatus'],drop_first=True)
df=pd.concat([df,status],axis=1)
df.head(4)
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
#
#   furnishingstatus  semi-furnished  unfurnished
# 0        furnished               0            0
# 1        furnished               0            0
# 2   semi-furnished               1            0
# 3        furnished               0            0

# %%
df.drop('furnishingstatus',axis=1,inplace=True)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    semi-furnished  unfurnished
# 0               0            0
# 1               0            0
# 2               1            0
# 3               0            0
# 4               0            0

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)

# %%
plt.scatter(df["area"],df["price"])

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'semi-furnished', 'unfurnished'],
#       dtype='object')

# %%
X=df[['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad','guestroom', 'basement', 'hotwaterheating', 'airconditioning',
       'parking', 'prefarea', 'semi-furnished', 'unfurnished']]
y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=100)

# %% [markdown]
# # RFE

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

# %%
lm=LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
rfe=RFE(lm,10)
rfe=rfe.fit(X_train,y_train)

# %%
list(zip(X_train1.columns,rfe.support_,rfe.ranking_))
# Out:
# [('area', False, 4),
#  ('bedrooms', False, 3),
#  ('bathrooms', True, 1),
#  ('stories', True, 1),
#  ('mainroad', True, 1),
#  ('guestroom', True, 1),
#  ('basement', False, 2),
#  ('hotwaterheating', True, 1),
#  ('airconditioning', True, 1),
#  ('parking', True, 1),
#  ('prefarea', True, 1),
#  ('semi-furnished', True, 1),
#  ('unfurnished', True, 1)]

# %%
X_train.drop(["area",'bedrooms','basement'],axis=1,inplace=True)
X_train.head(4)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#      bathrooms  stories  mainroad  guestroom  hotwaterheating  \
# 80           1        2         1          0                1
# 197          2        2         0          0                0
# 496          1        1         1          0                0
# 259          1        1         1          0                0
#
#      airconditioning  parking  prefarea  semi-furnished  unfurnished
# 80                 0        1         1               1            0
# 197                1        1         0               1            0
# 496                0        0         0               0            1
# 259                1        1         0               0            0

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=100)

# %% [markdown]
# # Scaling-Minmaxscaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_train=pd.DataFrame(X_train,columns=X.columns) # store in another name as some dataframe. Because needs to be used as dataframe  for RFE
X_train
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype uint8, int32, int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 0    0.366420       0.4        0.0  0.333333       1.0        0.0       0.0
# 1    0.084829       0.4        0.5  0.333333       0.0        0.0       1.0
# 2    0.190426       0.2        0.0  0.000000       1.0        0.0       0.0
# 3    0.398099       0.2        0.0  0.000000       1.0        0.0       1.0
# 4    0.172826       0.4        0.0  0.333333       1.0        1.0       1.0
# 5    0.461897       0.4        0.0  0.000000       1.0        1.0       1.0
# 6    0.490496       0.4        0.0  0.000000       1.0        1.0       1.0
# 7    0.102429       0.4        0.0  0.333333       0.0        0.0       0.0
# 316              0.0              0.0  0.000000       1.0             0.0
# 317              0.0              1.0  1.000000       0.0             1.0
# 318              0.0              0.0  0.000000       0.0             0.0
# 319              0.0              0.0  0.333333       0.0             0.0
# 320              0.0              0.0  0.666667       0.0             1.0
# 321              0.0              0.0  0.000000       0.0             0.0
# 322              0.0              0.0  0.000000       0.0             0.0
# 323              0.0              1.0  0.666667       0.0             1.0
# 324              1.0              0.0  0.333333       0.0             1.0
# 325              0.0              1.0  0.000000       0.0             0.0
# 326              0.0              0.0  0.000000       0.0             0.0
#
#      unfurnished
# 0            0.0
# 1            0.0
# 2            1.0
# 3            0.0
# 4            1.0
# 5            0.0
# 6            1.0
# 7            0.0
# 8            0.0
# 9            1.0
# 10           0.0
# 11           0.0
# 12           0.0
# 13           0.0
# 14           0.0
# 15           0.0
# 16           0.0
# 17           0.0
# 18           0.0
# 19           0.0
# 20           0.0
# 21           0.0
# 22           1.0
# 23           1.0
# 24           0.0
# 25           0.0
# 26           1.0
# 27           0.0
# 28           0.0
# 29           0.0
# ..           ...
# 297          1.0
# 298          0.0
# 299          0.0
# 300          0.0
# 301          0.0
# 302          0.0
# 303          0.0
# 304          1.0
# 305          1.0
# 306          0.0
# 307          0.0
# 308          1.0
# 309          1.0
# 310          0.0
# 311          1.0
# 312          0.0
# 313          0.0
# 314          0.0
# 315          1.0
# 316          1.0
# 317          0.0
# 318          1.0
# 319          1.0
# 320          0.0
# 321          1.0
# 322          1.0
# 323          0.0
# 324          0.0
# 325          0.0
# 326          1.0
#
# [327 rows x 13 columns]

# %% [markdown]
# # Importing stats model

# %%
import statsmodels.api as sm
X_train_sm=sm.add_constant(X_train)
y_train=list(y_train)
lr=sm.OLS(y_train,X_train_sm).fit()

# %%
lr.params
# Out:
# const              2.098665e+06
# area               2.805300e+06
# bedrooms           4.422467e+05
# bathrooms          1.866314e+06
# stories            1.457194e+06
# mainroad           5.198091e+05
# guestroom          3.485213e+05
# basement           2.422047e+05
# hotwaterheating    8.337158e+05
# airconditioning    7.142238e+05
# parking            7.534596e+05
# prefarea           7.439988e+05
# semi-furnished    -1.007430e+05
# unfurnished       -4.623064e+05
# dtype: float64

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.667
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     48.15
# Date:                Mon, 09 Sep 2019   Prob (F-statistic):           1.08e-66
# Time:                        17:09:45   Log-Likelihood:                -4993.5
# No. Observations:                 327   AIC:                         1.001e+04
# Df Residuals:                     313   BIC:                         1.007e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            2.099e+06   2.72e+05      7.717      0.000    1.56e+06    2.63e+06
# area             2.805e+06   3.79e+05      7.402      0.000    2.06e+06    3.55e+06
# bedrooms         4.422e+05   4.64e+05      0.952      0.342   -4.72e+05    1.36e+06
# bathrooms        1.866e+06   2.83e+05      6.599      0.000    1.31e+06    2.42e+06
# stories          1.457e+06   2.43e+05      5.995      0.000    9.79e+05    1.94e+06
# mainroad         5.198e+05    1.8e+05      2.882      0.004    1.65e+05    8.75e+05
# guestroom        3.485e+05   1.68e+05      2.070      0.039    1.73e+04     6.8e+05
# basement         2.422e+05   1.39e+05      1.738      0.083    -3.2e+04    5.16e+05
# hotwaterheating  8.337e+05   2.82e+05      2.961      0.003     2.8e+05    1.39e+06
# airconditioning  7.142e+05   1.43e+05      4.990      0.000    4.33e+05    9.96e+05
# parking          7.535e+05   2.31e+05      3.264      0.001    2.99e+05    1.21e+06
# prefarea          7.44e+05   1.48e+05      5.011      0.000    4.52e+05    1.04e+06
# semi-furnished  -1.007e+05   1.49e+05     -0.676      0.499   -3.94e+05    1.92e+05
# unfurnished     -4.623e+05   1.65e+05     -2.808      0.005   -7.86e+05   -1.38e+05
# ==============================================================================
# Omnibus:                       95.599   Durbin-Watson:                   2.143
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              326.878
# Skew:                           1.261   Prob(JB):                     1.05e-71
# Kurtosis:                       7.198   Cond. No.                         14.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['Features']=X_train.columns
vif['VIF']=[variance_inflation_factor(X_train.values,i)for i in range(X_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF",ascending=False)
vif
# Out:
#            Features   VIF
# 1          bedrooms  7.31
# 4          mainroad  5.88
# 0              area  4.52
# 3           stories  2.83
# 11   semi-furnished  2.23
# 6          basement  2.03
# 9           parking  2.03
# 8   airconditioning  1.81
# 12      unfurnished  1.75
# 2         bathrooms  1.70
# 5         guestroom  1.51
# 10         prefarea  1.49
# 7   hotwaterheating  1.13

# %%
X=X.drop("semi-furnished",1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=100)

# %%
X_train_sm=sm.add_constant(X_train)
y_train=list(y_train)
lr=sm.OLS(y_train,X_train_sm).fit()
lr

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.666
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     52.21
# Date:                Mon, 09 Sep 2019   Prob (F-statistic):           1.83e-67
# Time:                        17:09:45   Log-Likelihood:                -4993.7
# No. Observations:                 327   AIC:                         1.001e+04
# Df Residuals:                     314   BIC:                         1.006e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            4.868e+04   3.25e+05      0.150      0.881   -5.92e+05    6.89e+05
# area              249.1166     33.153      7.514      0.000     183.886     314.347
# bedrooms         9.121e+04   9.27e+04      0.984      0.326   -9.12e+04    2.74e+05
# bathrooms        9.307e+05   1.41e+05      6.589      0.000    6.53e+05    1.21e+06
# stories          4.866e+05   8.09e+04      6.012      0.000    3.27e+05    6.46e+05
# mainroad         5.267e+05    1.8e+05      2.927      0.004    1.73e+05    8.81e+05
# guestroom        3.471e+05   1.68e+05      2.064      0.040    1.62e+04    6.78e+05
# basement         2.388e+05   1.39e+05      1.716      0.087    -3.5e+04    5.13e+05
# hotwaterheating  8.381e+05   2.81e+05      2.979      0.003    2.85e+05    1.39e+06
# airconditioning  7.223e+05   1.43e+05      5.068      0.000    4.42e+05       1e+06
# parking          2.504e+05   7.69e+04      3.258      0.001    9.92e+04    4.02e+05
# prefarea         7.447e+05   1.48e+05      5.020      0.000    4.53e+05    1.04e+06
# unfurnished     -3.955e+05   1.32e+05     -3.007      0.003   -6.54e+05   -1.37e+05
# ==============================================================================
# Omnibus:                       97.083   Durbin-Watson:                   2.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              337.074
# Skew:                           1.276   Prob(JB):                     6.39e-74
# Kurtosis:                       7.269   Cond. No.                     3.23e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.23e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['Features']=X_train.columns
vif['VIF']=[variance_inflation_factor(X_train.values,i)for i in range(X_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF",ascending=False)
vif
# Out:
#            Features    VIF
# 1          bedrooms  15.79
# 2         bathrooms  10.03
# 0              area   8.66
# 3           stories   7.95
# 4          mainroad   6.83
# 6          basement   2.02
# 9           parking   2.02
# 8   airconditioning   1.80
# 5         guestroom   1.50
# 10         prefarea   1.48
# 11      unfurnished   1.40
# 7   hotwaterheating   1.13

# %%
X=X.drop("bedrooms",1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=100)

# %%
X_train_sm=sm.add_constant(X_train)
y_train=list(y_train)
lr=sm.OLS(y_train,X_train_sm).fit()
lr

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     56.88
# Date:                Mon, 09 Sep 2019   Prob (F-statistic):           3.80e-68
# Time:                        17:09:46   Log-Likelihood:                -4994.2
# No. Observations:                 327   AIC:                         1.001e+04
# Df Residuals:                     315   BIC:                         1.006e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            2.301e+05   2.68e+05      0.858      0.391   -2.97e+05    7.58e+05
# area              249.1449     33.151      7.515      0.000     183.919     314.371
# bathrooms          9.6e+05   1.38e+05      6.954      0.000    6.88e+05    1.23e+06
# stories          5.162e+05   7.52e+04      6.868      0.000    3.68e+05    6.64e+05
# mainroad         5.092e+05   1.79e+05      2.844      0.005    1.57e+05    8.61e+05
# guestroom        3.462e+05   1.68e+05      2.059      0.040    1.53e+04    6.77e+05
# basement           2.6e+05   1.37e+05      1.892      0.059   -1.04e+04     5.3e+05
# hotwaterheating  8.426e+05   2.81e+05      2.996      0.003    2.89e+05     1.4e+06
# airconditioning  7.211e+05   1.43e+05      5.061      0.000    4.41e+05       1e+06
# parking          2.579e+05   7.65e+04      3.372      0.001    1.07e+05    4.08e+05
# prefarea         7.484e+05   1.48e+05      5.047      0.000    4.57e+05    1.04e+06
# unfurnished     -4.026e+05   1.31e+05     -3.066      0.002   -6.61e+05   -1.44e+05
# ==============================================================================
# Omnibus:                      100.213   Durbin-Watson:                   2.159
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              357.139
# Skew:                           1.311   Prob(JB):                     2.81e-78
# Kurtosis:                       7.398   Cond. No.                     2.79e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.79e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['Features']=X_train.columns
vif['VIF']=[variance_inflation_factor(X_train.values,i)for i in range(X_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF",ascending=False)
vif
# Out:
#            Features   VIF
# 0              area  8.22
# 1         bathrooms  8.03
# 3          mainroad  6.66
# 2           stories  6.33
# 8           parking  2.01
# 5          basement  1.90
# 7   airconditioning  1.79
# 4         guestroom  1.48
# 9          prefarea  1.47
# 10      unfurnished  1.36
# 6   hotwaterheating  1.13

# %%
X=X.drop("basement",1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=100)

# %%
X_train_sm=sm.add_constant(X_train)
y_train=list(y_train)
lr=sm.OLS(y_train,X_train_sm).fit()
lr

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.661
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     61.71
# Date:                Mon, 09 Sep 2019   Prob (F-statistic):           2.72e-68
# Time:                        17:09:46   Log-Likelihood:                -4996.1
# No. Observations:                 327   AIC:                         1.001e+04
# Df Residuals:                     316   BIC:                         1.006e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             3.37e+05   2.63e+05      1.281      0.201   -1.81e+05    8.55e+05
# area              245.8515     33.240      7.396      0.000     180.451     311.252
# bathrooms        9.836e+05   1.38e+05      7.125      0.000    7.12e+05    1.26e+06
# stories          4.818e+05   7.32e+04      6.580      0.000    3.38e+05    6.26e+05
# mainroad         5.148e+05    1.8e+05      2.864      0.004    1.61e+05    8.68e+05
# guestroom        4.562e+05   1.58e+05      2.879      0.004    1.44e+05    7.68e+05
# hotwaterheating  8.614e+05   2.82e+05      3.053      0.002    3.06e+05    1.42e+06
# airconditioning  7.443e+05   1.43e+05      5.221      0.000    4.64e+05    1.02e+06
# parking          2.573e+05   7.68e+04      3.351      0.001    1.06e+05    4.08e+05
# prefarea         7.923e+05   1.47e+05      5.388      0.000    5.03e+05    1.08e+06
# unfurnished     -4.229e+05   1.31e+05     -3.218      0.001   -6.81e+05   -1.64e+05
# ==============================================================================
# Omnibus:                      100.184   Durbin-Watson:                   2.168
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              354.159
# Skew:                           1.313   Prob(JB):                     1.25e-77
# Kurtosis:                       7.370   Cond. No.                     2.72e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.72e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['Features']=X_train.columns
vif['VIF']=[variance_inflation_factor(X_train.values,i)for i in range(X_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF",ascending=False)
vif
# Out:
#           Features   VIF
# 0             area  8.21
# 1        bathrooms  7.65
# 3         mainroad  6.57
# 2          stories  6.09
# 7          parking  2.01
# 6  airconditioning  1.79
# 8         prefarea  1.45
# 9      unfurnished  1.36
# 4        guestroom  1.33
# 5  hotwaterheating  1.13

# %%
X=X.drop("area",1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=100)
X_train_sm=sm.add_constant(X_train)
y_train=list(y_train)
lr=sm.OLS(y_train,X_train_sm).fit()
lr
print(lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.591
# Method:                 Least Squares   F-statistic:                     53.43
# Date:                Mon, 09 Sep 2019   Prob (F-statistic):           2.25e-58
# Time:                        17:09:47   Log-Likelihood:                -5022.2
# No. Observations:                 327   AIC:                         1.006e+04
# Df Residuals:                     317   BIC:                         1.010e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             1.07e+06   2.64e+05      4.062      0.000    5.52e+05    1.59e+06
# bathrooms        1.069e+06   1.49e+05      7.188      0.000    7.77e+05    1.36e+06
# stories          4.545e+05   7.91e+04      5.747      0.000    2.99e+05     6.1e+05
# mainroad         8.058e+05    1.9e+05      4.249      0.000    4.33e+05    1.18e+06
# guestroom        5.999e+05    1.7e+05      3.527      0.000    2.65e+05    9.34e+05
# hotwaterheating  9.836e+05   3.05e+05      3.229      0.001    3.84e+05    1.58e+06
# airconditioning  8.741e+05   1.53e+05      5.714      0.000    5.73e+05    1.18e+06
# parking          4.084e+05      8e+04      5.102      0.000    2.51e+05    5.66e+05
# prefarea         9.928e+05   1.56e+05      6.351      0.000    6.85e+05     1.3e+06
# unfurnished     -4.751e+05   1.42e+05     -3.348      0.001   -7.54e+05   -1.96e+05
# ==============================================================================
# Omnibus:                      100.470   Durbin-Watson:                   2.171
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              359.550
# Skew:                           1.313   Prob(JB):                     8.41e-79
# Kurtosis:                       7.416   Cond. No.                         13.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif=pd.DataFrame()
vif['Features']=X_train.columns
vif['VIF']=[variance_inflation_factor(X_train.values,i)for i in range(X_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF",ascending=False)
vif
# Out:
#           Features   VIF
# 0        bathrooms  6.77
# 1          stories  6.08
# 2         mainroad  5.26
# 6          parking  1.86
# 5  airconditioning  1.77
# 7         prefarea  1.40
# 8      unfurnished  1.35
# 3        guestroom  1.31
# 4  hotwaterheating  1.12

# %%
X=X.drop("bathrooms",1)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=100)
X_train_sm=sm.add_constant(X_train)
y_train=list(y_train)
lr=sm.OLS(y_train,X_train_sm).fit()
lr
print(lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.538
# Model:                            OLS   Adj. R-squared:                  0.526
# Method:                 Least Squares   F-statistic:                     46.28
# Date:                Mon, 09 Sep 2019   Prob (F-statistic):           5.36e-49
# Time:                        17:09:47   Log-Likelihood:                -5046.9
# No. Observations:                 327   AIC:                         1.011e+04
# Df Residuals:                     318   BIC:                         1.015e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            2.158e+06   2.32e+05      9.287      0.000     1.7e+06    2.62e+06
# stories          6.084e+05    8.2e+04      7.422      0.000    4.47e+05     7.7e+05
# mainroad         6.914e+05   2.03e+05      3.398      0.001    2.91e+05    1.09e+06
# guestroom        7.061e+05   1.82e+05      3.871      0.000    3.47e+05    1.06e+06
# hotwaterheating  1.237e+06   3.26e+05      3.796      0.000    5.96e+05    1.88e+06
# airconditioning  9.957e+05   1.64e+05      6.082      0.000    6.74e+05    1.32e+06
# parking          4.739e+05   8.56e+04      5.535      0.000    3.05e+05    6.42e+05
# prefarea         1.036e+06   1.68e+05      6.158      0.000    7.05e+05    1.37e+06
# unfurnished      -5.83e+05   1.52e+05     -3.837      0.000   -8.82e+05   -2.84e+05
# ==============================================================================
# Omnibus:                       94.717   Durbin-Watson:                   2.174
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              300.659
# Skew:                           1.279   Prob(JB):                     5.16e-66
# Kurtosis:                       6.941   Cond. No.                         12.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif=pd.DataFrame()
vif['Features']=X_train.columns
vif['VIF']=[variance_inflation_factor(X_train.values,i)for i in range(X_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif=vif.sort_values(by="VIF",ascending=False)
vif
# Out:
#           Features   VIF
# 1         mainroad  4.65
# 0          stories  4.49
# 5          parking  1.80
# 4  airconditioning  1.75
# 6         prefarea  1.40
# 7      unfurnished  1.33
# 2        guestroom  1.30
# 3  hotwaterheating  1.10

# %% [markdown]
# # For test data

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred=lm.predict(X_test)

# %%
y_pred_train=lm.predict(X_train)

# %%
print(lm.intercept_)
# Out:
# 2158013.6823669155

# %%
print(lm.coef_)
# Out:
# [ 608389.67122073  691380.62123967  706051.25450235 1236889.9020443
#   995653.69596508  473931.69895892 1035562.18972836 -582980.82430177]

# %%
len(y_pred)
# Out:
# 218

# %%
len(y_test)
# Out:
# 218

# %%
from sklearn import metrics
metrics.r2_score(y_test,y_pred)
# Out:
# 0.5085836126765407

# %%
metrics.r2_score(y_train,y_pred_train)
# Out:
# 0.5379361976803041

# %%
#X=df[['mainroad','stories','parking','airconditioning','prefarea','unfurnished','guestroom','hotwaterheating']]

# %%
#X_test=scaler.transform(X_test)
#X_test=pd.DataFrame(X_test,columns=X.columns) # store in another name as some dataframe. Because needs to be used as dataframe  for RFE
#X_test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-425-bc66ddb89594> in <module>
# ----> 1 X_test=scaler.transform(X_test)
#       2 X_test=pd.DataFrame(X_test,columns=X.columns) # store in another name as some dataframe. Because needs to be used as dataframe  for RFE
#       3 X_test
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in transform(self, X)
#     385                         force_all_finite="allow-nan")
#     386
# --> 387         X *= self.scale_
#     388         X += self.min_
#     389         return X
#
# ValueError: operands could not be broadcast together with shapes (218,8) (13,) (218,8)

# %%
#X_test_sm=sm.add_constant(X_test)
#y_test=list(y_test)
#lr=sm.OLS(y_test,X_test_sm).fit()

# %%
#print(lr.summary())

# %%
#vif=pd.DataFrame()
#vif['Features']=X_test.columns
#vif['VIF']=[variance_inflation_factor(X_test.values,i)for i in range(X_test.shape[1])]
#vif['VIF']=round(vif['VIF'],2)
#vif=vif.sort_values(by="VIF",ascending=False)
#vif

# %% [markdown]
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
plt.scatter(range(len(y_test)),y_test,color='b')
plt.scatter(range(len(y_pred)),y_pred,color='r')
